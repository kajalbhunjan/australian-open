# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
import seaborn as sns

# %matplotlib inline

# %%
atp20 = pd.read_csv('./data/atp_matches_2020.csv')

# %%
atp20.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-8888      Atp Cup    Hard         24             A      20200106
# 1  2020-8888      Atp Cup    Hard         24             A      20200106
# 2  2020-8888      Atp Cup    Hard         24             A      20200106
# 3  2020-8888      Atp Cup    Hard         24             A      20200106
# 4  2020-8888      Atp Cup    Hard         24             A      20200106
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     104925         NaN          NaN  ...    51.0     39.0
# 1        299     105138         NaN          NaN  ...    35.0     21.0
# 2        298     104925         NaN          NaN  ...    57.0     35.0
# 3        297     105583         NaN          NaN  ...    54.0     39.0
# 4        296     104745         NaN          NaN  ...    55.0     37.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# ...

# %%
ao20 = atp20[atp20.tourney_name == 'Australian Open']

# %%
ao20.head()
# Out:
#     tourney_id     tourney_name surface  draw_size tourney_level  \
# 167   2020-580  Australian Open    Hard        128             G
# 168   2020-580  Australian Open    Hard        128             G
# 169   2020-580  Australian Open    Hard        128             G
# 170   2020-580  Australian Open    Hard        128             G
# 171   2020-580  Australian Open    Hard        128             G
#
#      tourney_date  match_num  winner_id winner_seed winner_entry  ... l_1stIn  \
# 167      20200120        100     104745           1          NaN  ...    64.0
# 168      20200120        101     105643         NaN          NaN  ...    60.0
# 169      20200120        102     105376           Q          NaN  ...    80.0
# 170      20200120        103     105807          27          NaN  ...    66.0
# 171      20200120        104     106401          23          NaN  ...    66.0
#
#     l_1stWon  l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank  \
# ...

# %%
ao20.drop(['winner_seed', 'loser_seed','winner_ht','loser_ht', 'surface','tourney_name','draw_size', 'winner_entry','loser_entry', 'winner_ioc', 'loser_ioc', 'winner_hand','loser_hand','tourney_level','tourney_date', 'w_bpFaced','l_bpFaced', 'best_of', 'loser_rank_points', 'winner_rank_points'], axis=1, inplace=True)
# Out:
# /Users/kbhunjan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
